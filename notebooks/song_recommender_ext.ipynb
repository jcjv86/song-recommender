# %% [markdown]
# ![alternative text](../src/img/logo_back.png)

# %% [markdown]
# #### The song recommender

# %%
import pandas as pd
import numpy as np
import sys
sys.path.insert(1, '../src/lib')
import os
import warnings
warnings.simplefilter('ignore')
import yaml
import time
import pickle
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from config import *
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials
from IPython.display import HTML
import matplotlib.pyplot as plt
from math import pi
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id= client_id,
                                                           client_secret= client_secret))

# %%
with open ("../config.yaml", 'r') as file:
    config = yaml.safe_load(file)

# %%
sys.path.insert(0, os.path.abspath(config['lib']))
import functions as funk

# %%
sys.path.insert(0, os.path.abspath(config['lib']))
import functions_ext as funk

# %%
database = pd.read_csv(config['data']+'uspop.csv')

# %%
funk.song_recommender(database)
# Out:
# Please enter song title:
#
#  lust for life
#
# Please enter artist name:
#
#  iggy pop
# 1 .
#
# song name:  Lust For Life
# artist name:  Iggy Pop
# url:  https://open.spotify.com/track/21YxK0klhpfLW8budkJaMF
#
# 2 .
#
# song name:  Lust For Life
# artist name:  Iggy Pop
# url:  https://open.spotify.com/track/0kvH59HS2T2m4bsXJhBGNC
#
# 3 .
#
# song name:  Lust For Life (with The Weeknd)
# artist name:  Lana Del Rey
# url:  https://open.spotify.com/track/0mt02gJ425Xjm7c3jYkOBn
#
# 4 .
#
# song name:  Lust For Life - The Prodigy Remix
# artist name:  Iggy Pop
# url:  https://open.spotify.com/track/5JLrVTFMGGeeB5Iz4Oci0R
#
# 5 .
#
# song name:  The Passenger
# artist name:  Iggy Pop
# url:  https://open.spotify.com/track/15BQ7vEDv2LJuh8TxWIhtd
# Which song would you prefer? Please enter a number from the list above:
#  1
# How many songs do you want us to recommend you? Maximum 20!
#  5
# Displaying 5 similar song(s) to your selection:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>title</th>
#       <th>artist</th>
#       <th>url</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>11539</th>
#       <td>Dance With Mr. Domino</td>
#       <td>Fats Domino</td>
#       <td><a href="https://open.spotify.com/track/2gZlblsff9FKnhSIwB2ZsU">https://open.spotify.com/track/2gZlblsff9FKnhSIwB2ZsU</a></td>
#     </tr>
#     <tr>
#       <th>13354</th>
#       <td>Do It Again (Put Ya Hands Up)</td>
#       <td>Jay-Z Featuring Beanie Sigel</td>
#       <td><a href="https://open.spotify.com/track/72Bz4ciRZPBcVSw0nrZDHi">https://open.spotify.com/track/72Bz4ciRZPBcVSw0nrZDHi</a></td>
#     </tr>
#     <tr>
#       <th>13043</th>
#       <td>She's Just My Style</td>
#       <td>Gary Lewis & The Playboys</td>
#       <td><a href="https://open.spotify.com/track/61Qh466Q63M4uckeYrYeal">https://open.spotify.com/track/61Qh466Q63M4uckeYrYeal</a></td>
#     </tr>
#     <tr>
#       <th>12666</th>
#       <td>All That She Wants</td>
#       <td>Ace Of Base</td>
#       <td><a href="https://open.spotify.com/track/7vtYEPFiFdFxkWmvaM6Brt">https://open.spotify.com/track/7vtYEPFiFdFxkWmvaM6Brt</a></td>
#     </tr>
#     <tr>
#       <th>5336</th>
#       <td>Let The Heartaches Begin</td>
#       <td>Long John Baldry</td>
#       <td><a href="https://open.spotify.com/track/1b6O88K7d9jluz6wac2kKD">https://open.spotify.com/track/1b6O88K7d9jluz6wac2kKD</a></td>
#     </tr>
#   </tbody>
# </table>
# These are the features of the song you selected:
#  Lust For Life by Iggy Pop
# This is the explanation of the features. They are measured on a scale from 0 to 1:
#
# -Energy: represents how intense and active the song is.
# -Danceability: describes how suitable a track is for dancing.
# -Valence: a measure describing the musical positiveness. The higher, the more cheerful.
# -Liveness: detects if the track was recorded live.
# -Instrumentalness: track contains no vocals.
# -Acousticness: possibility of the track being acoustic.
# -Speechiness: Speechiness detects the presence of spoken words in a track.
